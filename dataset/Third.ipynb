# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df0 = pd.read_csv("/content/drive/My Drive/general_tweets.csv")

# %%
df1 = pd.read_csv("/content/drive/My Drive/tweets_final_1.csv", engine='python')
df2 = pd.read_csv("/content/drive/My Drive/tweets_final_2.csv", engine='python')
df3 = pd.read_csv("/content/drive/My Drive/tweets_final_3.csv", engine='python')

# %%
pd.set_option('display.max_colwidth', None)

# %%
df0.head(2)
# Out:
#    Unnamed: 0             ID  \
# 0           0  2018-En-03364
# 1           1  2018-En-02478
#
#                                                                                                                                         Tweet  \
# 0  @JustinJeffre mornin sexy phantom crush hottie happy tremendous totally fun Tuesday love n hugs enjoy it xxoo love yas tons n bunches xxoo
# 1                                                                                                 @IvankaTrump What's up w the profile pic??
#
#   Affect Dimension  Intensity Score  target
# 0             fear            0.115       0
# 1          sadness            0.231       0

# %%
df1.head(2)
# Out:
#    Unnamed: 0                   id      conversation_id        date  \
# 0           0  1501931234154344448  1501931234154344448  2022-03-10
# 1           1  1501929422965907457  1501929422965907457  2022-03-10
#
#       username  \
# 0   bibipolar2
# 1  annesimonev
#
#                                                                                  tweet_processed  \
# 0  I am always too much, all of the time.   My presence = annoyance.   Why am I even here?
# 1           Tumbling over in my mind Thoughts of myself drift A nightmare of wasted space
#
#                                                        hashtags  \
# 0                 ['bipolarclub', 'bpd', 'depression', 'alone']
# 1  ['haikuchallenge', 'depression', 'drifting', 'reversehaiku']
#
#                                                                                                                          tweet_original  \
# 0        I am always too much, all of the time.   My presence = annoyance.   Why am I even here?   #bipolarclub #bpd #depression #alone
# 1  Tumbling over in my mind Thoughts of myself drift A nightmare of wasted space    #HaikuChallenge #depression #drifting #reversehaiku
#
#    target
# 0       1
# 1       1

# %%
df2.head(2)
# Out:
#    Unnamed: 0                   id      conversation_id        date  \
# 0         781  1501547436434546697  1501546671389372416  2022-03-09
# 1         785  1501546889413816322  1501546889413816322  2022-03-09
#
#           username  \
# 0  imheret45140132
# 1  macford57510386
#
#                                                                                    tweet_processed  \
# 0                                         @Iamdepr47974144 How can I best support you right now?
# 1  For everyone who's been asking for mushrooms are now on the menu🍄🍄🍄     https://t.co/60u9djN5Ge
#
#                                   hashtags  \
# 0           ['mentalhealth', 'depression']
# 1  ['psilocybin', 'depression', 'anxiety']
#
#                                                                                                                   tweet_original  \
# 0                                               @Iamdepr47974144 How can I best support you right now? #mentalhealth #depression
# 1  For everyone who's been asking for mushrooms are now on the menu🍄🍄🍄 #Psilocybin #depression #anxiety  https://t.co/60u9djN5Ge
#
#    target
# 0       1
# 1       1

# %%
df3.head(2)
# Out:
#    Unnamed: 0                   id      conversation_id        date  \
# 0         446  1499545197381922834  1499545197381922834  2022-03-04
# 1         454  1499521832743022592  1499521832743022592  2022-03-03
#
#           username  \
# 0  gameove16962194
# 1     fridabranwen
#
#                                                                                                                                                                                                                                        tweet_processed  \
# 0                                                       Day 5 of updates: Still living in my mini its cold at night Didnt eat today 😕 Everytime i post something i have someone in my dms tryimg to scam me Dont know how much longer i can go for
# 1  What to do with a lack of intimacy in an otherwise healthy relationship? He's  &amp; I have . He says it's not personal but regardless, lack of intimacy is SO painful for me so I pull back too😔 He finds it really hard to talk about feelings.
#
#                                                 hashtags  \
# 0  ['struggle', 'homelessness', 'homeless', 'depressed']
# 1   ['depressed', 'cptsd', 'relationshipadvice', 'help']
#
#                                                                                                                                                                                                                                                                                 tweet_original  \
# 0                                                      Day 5 of updates: Still living in my mini its cold at night Didnt eat today 😕 Everytime i post something i have someone in my dms tryimg to scam me Dont know how much longer i can go for #Struggle #homelessness #Homeless #depressed
# 1  What to do with a lack of intimacy in an otherwise healthy relationship? He's #depressed &amp; I have #CPTSD. He says it's not personal but regardless, lack of intimacy is SO painful for me so I pull back too😔 He finds it really hard to talk about feelings. #RelationshipAdvice #help
#
#    target
# 0       1
# 1       1

# %%
fig = plt.figure(figsize=(15,8))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

ax1 = fig.add_subplot(2,3,1)
sns.countplot(x='target', data=df1)
ax1.set(title="target distribution - df1")

ax2 = fig.add_subplot(2,3,2)
sns.countplot(x='target', data=df2)
ax2.set(title="target distribution - df2")

ax3 = fig.add_subplot(2,3,3)
sns.countplot(x='target', data=df3)
ax3.set(title="target distribution - df3")
# Out:
# [Text(0.5, 1.0, 'target distribution - df3')]

# %%
fig = plt.figure(figsize=(5,3))
plt.title('distribution of non-depressive dataset')
ax = sns.barplot(x=df0.target.unique(),y=df0.target.value_counts());
ax.set(xlabel='Labels');

# %%
df0 = df0[['Tweet','Affect Dimension','target']].copy()

df1 = df1[['tweet_processed','target']].copy()
df2 = df2[['tweet_processed','target']].copy()
df3 = df3[['tweet_processed','target']].copy()

# %%
df0 = df0.rename(columns = {"Tweet": "tweet"}) 
df0 = df0.rename(columns = {"Affect Dimension": "Affect_Dimension"}) 

df1 = df1.rename(columns = {"tweet_processed": "tweet"}) 
df2 = df2.rename(columns = {"tweet_processed": "tweet"}) 
df3 = df3.rename(columns = {"tweet_processed": "tweet"})

# %%
df_all = pd.concat([df0, df1, df2, df3])

# %%
df_all = df_all.sample(frac=1).reset_index(drop=True)
df_all.head(50)
# Out:
#                                                 tweet Affect_Dimension target
# 0   Best evening adult drink w/chocolate #satisfac...              joy      0
# 1   A SPELLBINDING performance by @DebsNewbold. El...              joy      0
# 2                   @LogitechUK Been there done that              fear      0
# 3   I love #tattoos but seriously #justtattooofus ...            anger      0
# 4   Well. Its been like two weeks and I still feel...              NaN      1
# 5   Looking for good news today...not finding any ...          sadness      1
# 6   I have depression. So, If I think "I have to" ...              NaN      1
# 7   Vin Diesel is pretty cool. I have seen him in ...              joy      0
# 8                                                 NaN              NaN    NaN
# 9   @Liz_Hanbury Oh no, jumper on again, has it tu...          sadness      0
# 10  Our loved ones would openly share the length a...              NaN      1
# 11  It's so sad when you talk so highly of someone...          sadness      1
# 12  @S1dharthM @Asli_Jacqueline @foxstarhindi @kri...              joy      0
# 13  All I want to do is sleep. My dreams are bizar...          sadness      1
# 14  Good morning family to all of you who took the...              joy      0
# 15  Really thought I was gonna have a family with ...              NaN      1
# 16  Jay Z came out of retirement just to drop the ...          sadness      0
# 17                             All fucking day                     NaN      1
# 18  @dp_srk_rk It's going 3 only. He has berdych t...          sadness      0
# 19  About to watch the eclipse in astral valley wi...              joy      0
# 20  Today(2/9/22)was rough, the morning was okay b...              NaN      1
# 21       @khizthigh Lol idk really :S khair good luck          sadness      0
# 22  Who wants hot snapping?\nAdd me : rchar28 \n #...            anger      0
# 23  Today is your day... \nSoar your spirit. \nUnf...              joy      0
# 24  Real happiness comes from the person who you t...              joy      0
# 25  First counselling session today. Quite nervous...              NaN      1
# 26  is, as usual, Twitter is harassing people with...              NaN      1
# 27  @AGavrielatos Where I am, extras are being han...              NaN      1
# 28  MY DAD'S  BROKE in 97 NOW I EXIST SO I CAN PAY...              NaN      1
# 29  Don't let anyone steal your joy! #rejoice #vic...              joy      0
# 30  @seanhannity Why are we still talking about th...             fear      0
# 31  And yet again, @MarliePacker sets the back row...              joy      0
# 32  No Smoking Day 2022.  We challenge you to stop...              NaN      1
# 33  I hope my eyes were camera that records all ha...              joy      0
# 34  When @Jaclynhill and @JeffreeStar  snap chats ...              joy      0
# 35  @jaden_lindner If I acquire a deadly scowl lik...            anger      0
# 36  seeing sope perform otsukare always makes me h...             fear      0
# 37  My life has been a #crazy, #painful, #awful jo...          sadness      1
# 38                                                NaN              NaN    NaN
# 39  Seriously, why do people punish children for '...             fear      0
# 40                                                NaN              NaN    NaN
# 41  #31DaysOfJoy Laughter brings me so much joy! I...              joy      0
# 42  Why is everyday great but still hard to get th...              NaN      1
# 43  #Bible reading today shows us the Lord has don...              joy      0
# 44  Just seeing school idols fills me with energy,...              joy      0
# 45  @cteeezy Lmfao look at it sober . 7102017 says...          sadness      0
# 46  @Tayylittle Mmm..is there any other way to sta...              joy      0
# 47  About to say fuck Satan if he ain't coming, Di...              NaN      1
# 48  Because so much “rubble” has happened, and bec...              NaN      1
# 49                   Don't let depression best you                 NaN      1

# %%
df_all.Affect_Dimension = df_all.Affect_Dimension.fillna('Depression')

# %%
df_all.head(50)
# Out:
#                                                 tweet Affect_Dimension target
# 0   Best evening adult drink w/chocolate #satisfac...              joy      0
# 1   A SPELLBINDING performance by @DebsNewbold. El...              joy      0
# 2                   @LogitechUK Been there done that              fear      0
# 3   I love #tattoos but seriously #justtattooofus ...            anger      0
# 4   Well. Its been like two weeks and I still feel...       Depression      1
# 5   Looking for good news today...not finding any ...          sadness      1
# 6   I have depression. So, If I think "I have to" ...       Depression      1
# 7   Vin Diesel is pretty cool. I have seen him in ...              joy      0
# 8                                                 NaN       Depression    NaN
# 9   @Liz_Hanbury Oh no, jumper on again, has it tu...          sadness      0
# 10  Our loved ones would openly share the length a...       Depression      1
# 11  It's so sad when you talk so highly of someone...          sadness      1
# 12  @S1dharthM @Asli_Jacqueline @foxstarhindi @kri...              joy      0
# 13  All I want to do is sleep. My dreams are bizar...          sadness      1
# 14  Good morning family to all of you who took the...              joy      0
# 15  Really thought I was gonna have a family with ...       Depression      1
# 16  Jay Z came out of retirement just to drop the ...          sadness      0
# 17                             All fucking day              Depression      1
# 18  @dp_srk_rk It's going 3 only. He has berdych t...          sadness      0
# 19  About to watch the eclipse in astral valley wi...              joy      0
# 20  Today(2/9/22)was rough, the morning was okay b...       Depression      1
# 21       @khizthigh Lol idk really :S khair good luck          sadness      0
# 22  Who wants hot snapping?\nAdd me : rchar28 \n #...            anger      0
# 23  Today is your day... \nSoar your spirit. \nUnf...              joy      0
# 24  Real happiness comes from the person who you t...              joy      0
# 25  First counselling session today. Quite nervous...       Depression      1
# 26  is, as usual, Twitter is harassing people with...       Depression      1
# 27  @AGavrielatos Where I am, extras are being han...       Depression      1
# 28  MY DAD'S  BROKE in 97 NOW I EXIST SO I CAN PAY...       Depression      1
# 29  Don't let anyone steal your joy! #rejoice #vic...              joy      0
# 30  @seanhannity Why are we still talking about th...             fear      0
# 31  And yet again, @MarliePacker sets the back row...              joy      0
# 32  No Smoking Day 2022.  We challenge you to stop...       Depression      1
# 33  I hope my eyes were camera that records all ha...              joy      0
# 34  When @Jaclynhill and @JeffreeStar  snap chats ...              joy      0
# 35  @jaden_lindner If I acquire a deadly scowl lik...            anger      0
# 36  seeing sope perform otsukare always makes me h...             fear      0
# 37  My life has been a #crazy, #painful, #awful jo...          sadness      1
# 38                                                NaN       Depression    NaN
# 39  Seriously, why do people punish children for '...             fear      0
# 40                                                NaN       Depression    NaN
# 41  #31DaysOfJoy Laughter brings me so much joy! I...              joy      0
# 42  Why is everyday great but still hard to get th...       Depression      1
# 43  #Bible reading today shows us the Lord has don...              joy      0
# 44  Just seeing school idols fills me with energy,...              joy      0
# 45  @cteeezy Lmfao look at it sober . 7102017 says...          sadness      0
# 46  @Tayylittle Mmm..is there any other way to sta...              joy      0
# 47  About to say fuck Satan if he ain't coming, Di...       Depression      1
# 48  Because so much “rubble” has happened, and bec...       Depression      1
# 49                   Don't let depression best you          Depression      1

# %%
fig = plt.figure(figsize=(5,3))
plt.title('general (non-depressive) dataset')
ax = sns.barplot(x=df_all.target.unique(),y=df_all.target.value_counts());
ax.set(xlabel='Labels');
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-761a3a067614> in <module>()
#       1 fig = plt.figure(figsize=(5,3))
#       2 plt.title('general (non-depressive) dataset')
# ----> 3 ax = sns.barplot(x=df_all.target.unique(),y=df_all.target.value_counts());
#       4 ax.set(xlabel='Labels');
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3183                           estimator, ci, n_boot, units, seed,
#    3184                           orient, color, palette, saturation,
# -> 3185                           errcolor, errwidth, capsize, dodge)
#    3186
#    3187     if ax is None:
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1583         """Initialize the plotter."""
#    1584         self.establish_variables(x, y, hue, data, orient,
# -> 1585                                  order, hue_order, units)
#    1586         self.establish_colors(color, palette, saturation)
#    1587         self.estimate_statistic(estimator, ci, n_boot, seed)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     205                 # Group the numeric data
#     206                 plot_data, value_label = self._group_longform(vals, groups,
# --> 207                                                               group_names)
#     208
#     209                 # Now handle the hue levels for nested ordering
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in _group_longform(self, vals, grouper, order)
#     251
#     252         # Group the val data
# --> 253         grouped_vals = vals.groupby(grouper)
#     254         out_data = []
#     255         for g in order:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    1892             squeeze=squeeze,  # type: ignore[arg-type]
#    1893             observed=observed,
# -> 1894             dropna=dropna,
#    1895         )
#    1896
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     895                 observed=observed,
#     896                 mutated=self.mutated,
# --> 897                 dropna=self.dropna,
#     898             )
#     899
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     887                 dropna=dropna,
#     888             )
# --> 889             if not isinstance(gpr, Grouping)
#     890             else gpr
#     891         )
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/grouper.py in __init__(self, index, grouper, obj, level, sort, observed, in_axis, dropna)
#     467         self.level = level
#     468         self._orig_grouper = grouper
# --> 469         self.grouping_vector = _convert_grouper(index, grouper)
#     470         self._all_grouper = None
#     471         self._index = index
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/grouper.py in _convert_grouper(axis, grouper)
#     921     elif isinstance(grouper, (list, tuple, Series, Index, np.ndarray)):
#     922         if len(grouper) != len(axis):
# --> 923             raise ValueError("Grouper and axis must be same length")
#     924
#     925         if isinstance(grouper, (list, tuple)):
#
# ValueError: Grouper and axis must be same length

# %%
df_all.target.value_counts()
# Out:
# 0                                                                                                                                                                                       1131
# 1                                                                                                                                                                                        449
# 1                                                                                                                                                                                         60
# People who have never dealt with depression think it's just being sad or being in a bad mood. That's not what depression is for me                                                         1
# Tone deaf: to express an obtuse insensitivity or lack of perception on issues of public sentiment and suffering. The ship has sunk &amp                                                    1
# I'd give anything for a chance to just talk to my mom &amp                                                                                                                                 1
# ['depression', 'mentalhealthawareness', 'mentalhealth', 'anxietyfighter', 'anxiety', 'depressed']                                                                                          1
# ['deathanxiety', 'mentalhealth', 'depression', 'mothernature', 'sunflowers']                                                                                                               1
# 💜Take meds  💗Eat cookies 🔲Dishes 🔲Make pork tenderloin patty &amp                                                                                                                          1
#  exercises  Visit the Amazon web site and search for code B085KR583Y  Let me know how it helped you.      https://t.co/JB18kyjQLh                                                          1
# Nobody feels shame for getting the help they need for cancer or lung  disease...please do not feel shame for seeking help around a possible  mental illness such as #depression &amp       1
# Name: target, dtype: int64

# %%
df_all.to_csv("/content/drive/My Drive/tweets_combined1.csv")
